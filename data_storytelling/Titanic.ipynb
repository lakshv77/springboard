# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv', header=0)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
# Survived                   887 non-null int64
# Pclass                     887 non-null int64
# Name                       887 non-null object
# Sex                        887 non-null object
# Age                        887 non-null float64
# Siblings/Spouses Aboard    887 non-null int64
# Parents/Children Aboard    887 non-null int64
# Fare                       887 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.5+ KB

# %% [markdown]
# Let's analyze the data to see how many passengers survived and how the numbers are distributed between male and female population.

# %%
sns.factorplot(x='Survived', col='Sex', kind='count', data=df);

# %% [markdown]
# From the above plot, we can see of the ship's male population, only less than 25% survived, whereas of the ship's female population, more than two thirds seems to have survived.

# %% [markdown]
# Next, we can check the distributions among the passenger classes.

# %%
sns.factorplot(x='Survived', col='Pclass', kind='count', data=df);

# %% [markdown]
# Another way to visualize the above info side by side is to use a count plot with Pclass as hue.

# %%
plt.figure(figsize=(11,8))
sns.countplot(x='Survived', hue='Pclass', data=df)
plt.show()

# %% [markdown]
# Let's look at the age distribution of passengers. We can start with getting the summary statistics.

# %%
age = df['Age']
age.describe()
# Out:
# count    887.000000
# mean      29.471443
# std       14.121908
# min        0.420000
# 25%       20.250000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# The passengers range from 29 to 80 years. Let's make a histogram for the age distribution.

# %%
age.hist(bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Distplot for another way to do univariate analysis

# %%
age_dist = sns.distplot(age)
age_dist.set_title("Distribution of Passengers' Ages")
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
fare_dist = sns.distplot(df['Fare'])
fare_dist.set_title("Distribution of Fares")
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df['Fare'].hist(bins=20)
plt.xlabel('Fares')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Let's analyze the age distribution for passengers who survived vs who didn't.

# %%
sns.boxplot(x="Survived", y="Age", data=df)
plt.show()

# %% [markdown]
# From the above plot, we can see that the averages and interquartile ranges indicate that the population group that survived was younger than the group that didn't.

# %% [markdown]
# Now let's plot the bivariate relationship between fares and survival.

# %%
sns.boxplot(x="Survived", y="Fare", data=df)
plt.show()

# %% [markdown]
# The above plot indicates that the a good number passengers with higher fares survived when compared to those with lower fares. We can see high concentration of passengers that didn't survive with fares under 100.
#
# Perhaps the more expensive cabins had better safety features or enabled the passengers to survive in some way.
